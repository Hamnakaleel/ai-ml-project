# %%
# before start the Code install Tensorflow . To  install go to the Anaconda Prompt:Admin  (pip install tensorflow) if not this 
#code won't work

# %%
import os

dataset_path = "Train"

for disease in os.listdir(dataset_path):
    folder = os.path.join(dataset_path, disease)
    count = len(os.listdir(folder))
    print(f"{disease}: {count} images")
# Out:
# Bacterial diseases - Aeromoniasis: 250 images
# Bacterial gill disease: 250 images
# Bacterial Red disease: 250 images
# Fungal diseases Saprolegniasis: 250 images
# Healthy Fish: 250 images
# Parasitic diseases: 250 images

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Settings
IMG_SIZE = (128, 128)
BATCH_SIZE = 64

# Load and prepare training data
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    "Train",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    "Train",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

print("Classes found:", train_data.class_indices)
# Out:
# Found 1200 images belonging to 6 classes.
# Found 300 images belonging to 6 classes.
# Classes found: {'Bacterial Red disease': 0, 'Bacterial diseases - Aeromoniasis': 1, 'Bacterial gill disease': 2, 'Fungal diseases Saprolegniasis': 3, 'Healthy Fish': 4, 'Parasitic diseases': 5}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(6, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 126, 126, 32)        │             896 │
# ...

# %%
history = model.fit(
    train_data,
    epochs=5,
    validation_data=val_data
)

print("Training complete!")
# Out:
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.2083 - loss: 1.8580 - val_accuracy: 0.3167 - val_loss: 1.7701
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 671ms/step - accuracy: 0.2783 - loss: 1.6976 - val_accuracy: 0.4267 - val_loss: 1.6003
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 671ms/step - accuracy: 0.4225 - loss: 1.4989 - val_accuracy: 0.4267 - val_loss: 1.5025
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 668ms/step - accuracy: 0.4750 - loss: 1.4063 - val_accuracy: 0.4300 - val_loss: 1.5611
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 697ms/step - accuracy: 0.5325 - loss: 1.2612 - val_accuracy: 0.4600 - val_loss: 1.4209
# Training complete!

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Better data generator with augmentation
datagen2 = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

train_data2 = datagen2.flow_from_directory(
    "Train",
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data2 = datagen2.flow_from_directory(
    "Train",
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

early_stop = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

history2 = model.fit(
    train_data2,
    epochs=20,
    validation_data=val_data2,
    callbacks=[early_stop]
)

print("Done!")
# Out:
# Found 1200 images belonging to 6 classes.
# Found 300 images belonging to 6 classes.
# Epoch 1/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 591ms/step - accuracy: 0.4800 - loss: 1.3411 - val_accuracy: 0.4733 - val_loss: 1.3762
# Epoch 2/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 568ms/step - accuracy: 0.5258 - loss: 1.2359 - val_accuracy: 0.4133 - val_loss: 1.6046
# Epoch 3/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 578ms/step - accuracy: 0.5450 - loss: 1.2054 - val_accuracy: 0.5000 - val_loss: 1.3152
# Epoch 4/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 21s 557ms/step - accuracy: 0.5792 - loss: 1.1564 - val_accuracy: 0.4833 - val_loss: 1.3447
# Epoch 5/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 579ms/step - accuracy: 0.5950 - loss: 1.0773 - val_accuracy: 0.5200 - val_loss: 1.2934
# Epoch 6/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 579ms/step - accuracy: 0.6283 - loss: 0.9981 - val_accuracy: 0.5067 - val_loss: 1.3527
# Epoch 7/20
# ...

# %%
# accuracy is 83 and Val_Accuracy is 62  so it is overfitting... to fix this issue 
# i am going to use MOBILENET V2 pre_ trained model that already trained more than10,000 images

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout

# Load pretrained model
base_model = MobileNetV2(input_shape=(128,128,3), include_top=False, weights='imagenet')
base_model.trainable = False

# Add our custom layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(6, activation='softmax')(x)

model2 = Model(inputs=base_model.input, outputs=output)

model2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history3 = model2.fit(
    train_data2,
    epochs=15,
    validation_data=val_data2,
    callbacks=[EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)]
)

print("Done!")
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 119s 13us/step
# Epoch 1/15
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 38s 688ms/step - accuracy: 0.4633 - loss: 1.4846 - val_accuracy: 0.5433 - val_loss: 1.1483
# Epoch 2/15
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 21s 560ms/step - accuracy: 0.7058 - loss: 0.8497 - val_accuracy: 0.6267 - val_loss: 1.0087
# Epoch 3/15
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 21s 549ms/step - accuracy: 0.7700 - loss: 0.6460 - val_accuracy: 0.6433 - val_loss: 1.0141
# Epoch 4/15
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 565ms/step - accuracy: 0.8050 - loss: 0.5709 - val_accuracy: 0.7233 - val_loss: 0.9041
# Epoch 5/15
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 21s 562ms/step - accuracy: 0.8333 - loss: 0.4807 - val_accuracy: 0.7033 - val_loss: 0.8566
# Epoch 6/15
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 21s 558ms/step - accuracy: 0.8742 - loss: 0.3770 - val_accuracy: 0.7300 - val_loss: 0.7665
# Epoch 7/15
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 21s 554ms/step - accuracy: 0.9033 - loss: 0.2984 - val_accuracy: 0.7100 - val_loss: 0.8253
# Epoch 8/15
# ...

# %%
#save the model

# %%
model2.save("fish_disease_model.h5")
print("Model saved successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!

# %%
import os
files = os.listdir("Train/Healthy Fish")
print(files[:3])
# Out:
# ['Healthy Fish (1).jpeg', 'Healthy Fish (1).jpg', 'Healthy Fish (1).png']

# %%
# Test the prediction function on a healthy fish image
predict_fish("Train/Healthy Fish/Healthy Fish (1).jpg")
# Out:
#   Cell In[10], line 1
#     predict_fish("Train/Healthy Fish/Healthy Fish (1).jpg"
#                                                           ^
# _IncompleteInputError: incomplete input

# %%
import os
files = os.listdir("Train/Not a fish")
print(f"Total images: {len(files)}")
# Out:
# Total images: 167

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout

# Data generator with augmentation
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

train_data = datagen.flow_from_directory(
    "Train",
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    "Train",
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

print("Classes found:", train_data.class_indices)
# Out:
# Found 1324 images belonging to 7 classes.
# Found 331 images belonging to 7 classes.
# Classes found: {'Bacterial Red disease': 0, 'Bacterial diseases - Aeromoniasis': 1, 'Bacterial gill disease': 2, 'Fungal diseases Saprolegniasis': 3, 'Healthy Fish': 4, 'Not a fish': 5, 'Parasitic diseases': 6}

# %%
# Build MobileNetV2 model for 7 classes
base_model = MobileNetV2(input_shape=(128,128,3), include_top=False, weights='imagenet')
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(7, activation='softmax')(x)

model_new = Model(inputs=base_model.input, outputs=output)

model_new.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

history = model_new.fit(
    train_data,
    epochs=15,
    validation_data=val_data,
    callbacks=[early_stop]
)

print("Training complete!")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 43s 748ms/step - accuracy: 0.4826 - loss: 1.5218 - val_accuracy: 0.5861 - val_loss: 1.1485
# Epoch 2/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 563ms/step - accuracy: 0.7364 - loss: 0.7867 - val_accuracy: 0.6647 - val_loss: 0.9056
# Epoch 3/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 564ms/step - accuracy: 0.7923 - loss: 0.6282 - val_accuracy: 0.7069 - val_loss: 0.7746
# Epoch 4/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 559ms/step - accuracy: 0.8489 - loss: 0.4607 - val_accuracy: 0.6918 - val_loss: 0.8949
# Epoch 5/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 573ms/step - accuracy: 0.8474 - loss: 0.4173 - val_accuracy: 0.7492 - val_loss: 0.7635
# Epoch 6/15
# ...

# %%
#XCELLENT!! 🎉🎉🎉🔥🔥🔥
#Your new model results:

#✅ Training accuracy: 95.47%
#✅ Validation accuracy: 80.66%

# %%
model_new.save("fish_disease_model.h5")
print("Model saved!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved!

# %%
# Test prediction on a sample image
from tensorflow.keras.preprocessing import image as img_lib
import numpy as np

# Define class mapping (must match app.py)
class_mapping = {
    0: 'Bacterial Red disease',
    1: 'Bacterial diseases - Aeromoniasis',
    2: 'Bacterial gill disease',
    3: 'Fungal diseases Saprolegniasis',
    4: 'Healthy Fish',
    5: 'Not a fish',
    6: 'Parasitic diseases'
}

def predict_fish(image_path):
    """Predict disease for a given fish image"""
    test_img = img_lib.load_img(image_path, target_size=(128, 128))
    test_img_array = img_lib.img_to_array(test_img) / 255.0
    test_img_array = np.expand_dims(test_img_array, axis=0)
    
    prediction = model_new.predict(test_img_array)
    class_idx = int(np.argmax(prediction))
    confidence = round(float(np.max(prediction)) * 100, 2)
    disease = class_mapping[class_idx]
    
    print(f"Predicted: {disease}")
    print(f"Confidence: {confidence}%")
    return disease, confidence

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load test data
test_datagen = ImageDataGenerator(rescale=1./255)
test_data = test_datagen.flow_from_directory(
    "Train",
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Get predictions
predictions = model_new.predict(test_data)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_data.classes
class_labels = list(test_data.class_indices.keys())

# Plot confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
fig, ax = plt.subplots(figsize=(10,8))
disp.plot(ax=ax, xticks_rotation=45)
plt.title("Confusion Matrix - Fish Disease Detection")
plt.tight_layout()
plt.savefig("confusion_matrix.png")
plt.show()
print("Confusion matrix saved!")
# Out:
# Found 1655 images belonging to 7 classes.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 17
#       8 test_data = test_datagen.flow_from_directory(
#       9     "Train",
#      10     target_size=(128,128),
#    (...)     13     shuffle=False
#      14 )
#      16 # Get predictions
# ---> 17 predictions = model_new.predict(test_data)
#      18 predicted_classes = np.argmax(predictions, axis=1)
#      19 true_classes = test_data.classes
#
# NameError: name 'model_new' is not defined

# %%
if confidence < 50.0:
    return jsonify({
        'error': '⚠️ Low confidence! This does not appear to be a valid fish image. Please upload a clearer fish image!'
    })
# Out:
#   Cell In[2], line 2
#     return jsonify({
#     ^
# SyntaxError: 'return' outside function
